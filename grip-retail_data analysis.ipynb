# %%
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
data=pd.read_csv(r"C:\Users\kavya\OneDrive\Desktop\dwvl\SampleSuperstore.csv") 
df=pd.DataFrame(data)

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.size
# Out:
# 129922

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.Country.value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
data.Segment.value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
cnt=data.Segment.value_counts()[:15].to_frame().reset_index()
cnt.columns=['Segment','Sales']
cnt
# Out:
#        Segment  Sales
# 0     Consumer   5191
# 1    Corporate   3020
# 2  Home Office   1783

# %%
x=list(df.iloc[:,9])
y=list(df.iloc[:,1])

# %%
z=list(df.iloc[:,9])
plt.bar(x,z,color='b')
plt.title("sample super store")
plt.xlabel("ship mode")
plt.ylabel("sales")
plt.show()

# %%
a1=list(df.iloc[:,0])
a2=list(df.iloc[:,12])
plt.bar(a1,a2,color='r')
plt.title("sample super store")
plt.xlabel("ship mode")
plt.ylabel("profits")
plt.show()

# %%
plt.plot(x,y)

# %%
plt.scatter(x,z)
plt.show()

# %%
plt.scatter(x,y)
plt.show()
